# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
z = np.random.random()
z
# Out:
# 0.46499250959476046

# %%
x = 0
pasos = []

for i in range(n):
    x += 2 * np.random.random() - 1
    pasos.append(x)
plt.plot(pasos)

# %%
n = 100
for j in range(100):
    x = 0
    pasos = []
    
    for i in range(n):
        x += 2 * np.random.random() - 1
        pasos.append(x)
    plt.plot(pasos)

# %% [markdown]
# Ahora haremos un borracho en dos dimensiones.

# %% [markdown]
# ahora con pasos discretos

# %%
def paso():
    #codigo

# %% [markdown]
# Contenlo en una caja

# %%
def contener():
    #codigo

# %% [markdown]
# Ahora con vectores c:
